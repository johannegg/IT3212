# %% [markdown]
# # IT3212 - Assignment 1 - Group 44

# %% [markdown]
# ## Task 1

# %% [markdown]
# ## Task 2

# %% [markdown]
# ## Task 3

# %% [markdown]
# ## Task 4

# %% [markdown]
# ## Task 5

# %% [markdown]
# ## Task 6
